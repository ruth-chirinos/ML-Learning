# %% [markdown]
# <a href="https://colab.research.google.com/github/rutyroot/ML-Learning/blob/master/Python/Clustering/Clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn import datasets
import numpy as np

# %matplotlib inline

# %%
# Vamos a generar nuestro dataset
# blobs, classes = datasets.make_blobs(1000, centers=3,cluster_std=1.75)
# blobs, classes = datasets.make_blobs(n_samples=1000, centers=3, n_features=2,random_state=0)
blobs, classes = datasets.make_blobs(500, centers=5)

# %%
classes
# Out:
# array([1, 1, 4, 3, 0, 1, 2, 2, 3, 4, 2, 3, 1, 0, 3, 2, 1, 2, 0, 4, 1, 3,
#        1, 0, 4, 0, 1, 3, 4, 1, 0, 2, 3, 0, 0, 2, 4, 3, 2, 1, 4, 4, 1, 3,
#        1, 1, 3, 4, 0, 2, 3, 1, 2, 4, 3, 4, 3, 3, 1, 3, 0, 1, 1, 4, 1, 0,
#        2, 4, 3, 3, 0, 0, 1, 4, 1, 0, 1, 1, 2, 3, 4, 1, 0, 1, 4, 2, 3, 2,
#        2, 3, 2, 4, 1, 0, 2, 2, 4, 3, 2, 1, 4, 4, 2, 4, 0, 2, 2, 2, 1, 0,
#        1, 3, 2, 4, 4, 4, 4, 4, 2, 2, 0, 0, 4, 1, 3, 3, 3, 4, 0, 1, 1, 0,
#        2, 1, 0, 0, 4, 1, 3, 0, 2, 3, 2, 0, 4, 1, 3, 3, 1, 0, 0, 4, 4, 3,
#        1, 0, 0, 3, 2, 4, 3, 0, 3, 1, 4, 1, 1, 0, 4, 3, 0, 1, 2, 0, 4, 4,
#        4, 0, 2, 3, 2, 1, 3, 2, 0, 3, 1, 3, 0, 4, 3, 3, 3, 0, 1, 1, 0, 0,
#        1, 3, 2, 4, 4, 0, 1, 2, 0, 0, 1, 1, 0, 1, 4, 3, 3, 0, 4, 0, 4, 2,
#        3, 4, 3, 2, 1, 3, 3, 3, 1, 4, 4, 2, 2, 2, 4, 0, 0, 3, 3, 2, 1, 4,
#        4, 3, 4, 0, 2, 3, 4, 3, 3, 0, 3, 1, 1, 2, 2, 1, 2, 2, 0, 2, 0, 2,
#        1, 2, 3, 3, 3, 2, 3, 0, 1, 0, 0, 3, 1, 1, 2, 2, 3, 3, 2, 1, 4, 3,
# ...

# %%
import matplotlib.pyplot as plt

# %%
# Veamos nuestros datos
f, ax = plt.subplots(figsize=(7.5, 7.5))
ax.scatter(blobs[:, 0], blobs[:, 1])
rgb = np.array(['r', 'g', 'b','y', 'm'])
ax.set_title("Dataset")
# Out:
# Text(0.5, 1.0, 'Dataset')

# %%
from sklearn.cluster import KMeans

# %%
# Definamos el modelo de Kmeans
kmean = KMeans(n_clusters=5)

# %%
# Entrenemos el algoritmo
kmean.fit(blobs)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=5, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
# Los centroides
kmean.cluster_centers_
# Out:
# array([[ 3.24084138, -2.24931367],
#        [-7.84981949,  7.79268795],
#        [-6.53394206, -4.28235399],
#        [-4.27962563, -7.41663563],
#        [-3.16767646, -2.02391966]])

# %%
# Cluster definition
f, ax = plt.subplots(figsize=(7.5, 7.5))
ax.scatter(blobs[:, 0], blobs[:, 1], color=rgb[classes])
#ax.scatter(blobs[:, 0], blobs[:, 1])
print(kmean.cluster_centers_)
ax.scatter(kmean.cluster_centers_[:, 0],
           kmean.cluster_centers_[:, 1],
           marker='*', s=250,
           color='black', label='Centers')
ax.set_title("Blobs")
ax.legend(loc='best')
# Out:
# [[ 3.24084138 -2.24931367]
#  [-7.84981949  7.79268795]
#  [-6.53394206 -4.28235399]
#  [-4.27962563 -7.41663563]
#  [-3.16767646 -2.02391966]]

# %%
# Evaluar los datos con Elbow (TAREA!!)
# Introduction to Statistical Learning,  
# Book Deep Learning de Josua Bengio
# Introduction to Reinforcement Learning - Richard Sutton
